# %%
# The code was removed by Watson Studio for sharing.

# %%
import pandas as pd
import pickle
import cloudpickle as cp
from urllib.request import urlopen

# %%
recipes = pd.read_csv('https://raw.githubusercontent.com/mpc02002/Food.com_data/master/datasets-raw/RAW_recipes1.csv',index_col=0)
for i in [2,3,4,5]:
    recipes_append = pd.read_csv('https://raw.githubusercontent.com/mpc02002/Food.com_data/master/datasets-raw/RAW_recipes'+str(i)+'.csv',index_col=0)
    recipes = pd.concat([recipes,recipes_append],ignore_index=True)
recipes.set_index('id',inplace=True)

recipes
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 137739    arriba   baked winter squash mexican style       55           47892
# 31490               a bit different  breakfast pizza       30           26278
# 112140                     all in the kitchen  chili      130          196586
# 59389                             alouette  potatoes       45           68585
# 44061             amish  tomato ketchup  for canning      190           41706
# ...                                              ...      ...             ...
# 486161                                   zydeco soup       60          227978
# 493372                              zydeco spice mix        5         1500678
# 308080                     zydeco ya ya deviled eggs       40           37779
# 298512        cookies by design   cookies on a stick       29          506822
# 298509  cookies by design   sugar shortbread cookies       20          506822
#
# ...

# %%
interactions = pd.read_csv('https://raw.githubusercontent.com/mpc02002/Food.com_data/master/datasets-raw/RAW_interactions1.csv',index_col=0)
for i in [2,3,4,5]:
    inappend = pd.read_csv('https://raw.githubusercontent.com/mpc02002/Food.com_data/master/datasets-raw/RAW_interactions'+str(i)+'.csv',index_col=0)
    interactions = pd.concat([interactions,inappend],ignore_index=True)

interactions
# Out:
#             user_id  recipe_id        date  rating  \
# 0             38094      40893  2003-02-17       4
# 1           1293707      40893  2011-12-21       5
# 2              8937      44394  2002-12-01       4
# 3            126440      85009  2010-02-27       5
# 4             57222      85009  2011-10-01       5
# ...             ...        ...         ...     ...
# 1132362      116593      72730  2003-12-09       0
# 1132363      583662     386618  2009-09-29       5
# 1132364      157126      78003  2008-06-23       5
# 1132365       53932      78003  2009-01-11       4
# 1132366  2001868099      78003  2017-12-18       5
#
#                                                     review
# 0        Great with a salad. Cooked on top of stove for...
# 1        So simple, so delicious! Great for chilly fall...
# 2        This worked very well and is EASY.  I used not...
# 3        I made the Mexican topping and took it to bunk...
# ...

# %%
ingr_map = cp.load(urlopen("https://raw.githubusercontent.com/mpc02002/Food.com_data/master/datasets-raw/ingr_map.pkl"))
ingr_map.set_index('id',inplace=True)
ingr_map
# Out:
#                                                raw_ingr  raw_words  \
# id
# 4308  medium heads bibb or red leaf lettuce, washed,...         13
# 4308              mixed baby lettuces and spring greens          6
# 4308                               romaine lettuce leaf          3
# 4308                               iceberg lettuce leaf          3
# 4308                                red romaine lettuce          3
# ...                                                 ...        ...
# 6702                                           soybeans          1
# 3318                                              goose          1
# 47                                               ajwain          1
# 750                                            brinjals          1
# 4061                                              khoya          1
#
#                                               processed  len_proc replaced  \
# id
# 4308  medium heads bibb or red leaf lettuce, washed,...        73  lettuce
# ...

# %%
project.save_data('recipes.csv', recipes.to_csv(), set_project_asset=True, overwrite=True)
project.save_data('interactions.csv', interactions.to_csv(), set_project_asset=True, overwrite=True)
project.save_data('ingr_map.pkl', pickle.dumps(ingr_map), set_project_asset=True, overwrite=True)
# Out:
# {'file_name': 'ingr_map.pkl',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'foodcomrecipepopularitypredictor-donotdelete-pr-wiqbzxzcs7ksbf',
#  'asset_id': '06fa3121-912e-4f5a-b853-6ae64f602beb'}
